# %%
import numpy as np
import pandas as pd
import mne
import matplotlib.pyplot as plt

from bycycle.features import compute_features
from bycycle.cyclepoints import find_extrema, find_zerox
from bycycle.plts import plot_burst_detect_summary

# %%
# %matplotlib qt

# %%
raw = mne.io.read_raw_edf('../data/MESA/mesa-sleep-0002.edf', preload=True)
# Out:
# Extracting EDF parameters from /Users/elkosik/Projects/ecg_param/data/MESA/mesa-sleep-0002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 10137343  =      0.000 ... 39598.996 secs...

# %%
data, times = raw[:,:]

# %%
data.shape
# Out:
# (27, 10137344)

# %%
times.shape
# Out:
# (10137344,)

# %%
fs = 32

# %%
plt.plot(times[10000:12000], data[8][10000:12000])
plt.show()

# %%
plt.plot(times[10000:12000], data[11][10000:12000])
plt.show()

# %%
plt.plot(times, data[8])
plt.show()

# %%
raw.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EKG, EOG-L, EOG-R, EMG, EEG1, EEG2, EEG3, Pres, Flow, Snore, ...
#  chs: 27 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: 1985-01-01 20:29:59 UTC
#  nchan: 27
#  projs: []
#  sfreq: 256.0 Hz
# >

# %%
raw.info['ch_names']
# Out:
# ['EKG',
#  'EOG-L',
#  'EOG-R',
#  'EMG',
#  'EEG1',
#  'EEG2',
#  'EEG3',
#  'Pres',
#  'Flow',
#  'Snore',
#  'Thor',
#  'Abdo',
#  'Leg',
#  'Therm',
#  'Pos',
#  'EKG_Off',
#  'EOG-L_Off',
#  'EOG-R_Off',
#  'EMG_Off',
#  'EEG1_Off',
#  'EEG2_Off',
#  'EEG3_Off',
#  'Pleth',
#  'OxStatus',
#  'SpO2',
#  'HR',
#  'DHR']

# %%
raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1351x847 with 4 Axes>

# %%
raw.plot(n_channels=1, scalings='auto')
# Out:
# <MNEBrowseFigure size 1351x847 with 4 Axes>
# Channels marked as bad:
# none
# Channels marked as bad:
# none
